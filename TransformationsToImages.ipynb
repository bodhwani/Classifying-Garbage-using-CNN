# %%
from PIL import Image
import os, sys
import cv2
import os

# %% [markdown]
# # Transforming images into 64x64x3

# %%
hahah = []
path = "/Users/Vinit/Desktop/testing/data"
print path
h2=[]
temp = []
for i in (os.listdir(path)):
    if i != ".DS_Store" and i != "ImageTo64x64.ipynb":
        h2.append(i)
        sub_path = path+"/"+i
        if sub_path != ".DS_Store":
            h2.append(os.listdir(sub_path))
            temp = (os.listdir(sub_path))
            for a in temp:
                if(a!=".DS_Store"):
                    with open(sub_path + "/" + a, 'r+b') as f:
                        with Image.open(f) as image:
                            cover = resizeimage.resize_cover(image, [64, 64])
                            cover.save(sub_path + "/" + a, image.format)
print "Successfully transformed!"


        
# with open("/Users/Vinit/Desktop/testing/betula_alleghaniensis/13291661480019.jpg", 'r+b') as f:
#     with Image.open(f) as image:
#         cover = resizeimage.resize_cover(image, [64, 64])
#         cover.save("/Users/Vinit/Desktop/testing/betula_alleghaniensis/13291661480019.jpg", image.format)
# Out:
# /Users/Vinit/Desktop/testing/data
# Successfully transformed!

# %% [markdown]
# # Checking

# %%
matrix1 = cv2.imread("/Users/Vinit/Desktop/testing/data/betula_jacqemontii/1258480850_0002.jpg")
print matrix1.shape
# Out:
# (64, 64, 3)

# %% [markdown]
# # Removing items

# %%
hahah = []
path = "/Users/Vinit/Desktop/CSIhack/dataset"
print path
h2=[]
temp = []
count = 0
for i in (os.listdir(path)):
    if i != ".DS_Store" and i != "ImageTo64x64.ipynb":
        h2.append(i)
        sub_path = path+"/"+i
        if sub_path != ".DS_Store":
            h2.append(os.listdir(sub_path))
            temp = (os.listdir(sub_path))
            print "temp is ",temp
            for a in range(0,len(temp)):
                if(temp[a]!=".DS_Store"):
                    print "\n a and temp[a] is ",a,temp[a]
                    if(a>134):
                        removepath = sub_path + "/" + temp[a]
                        print "\nremove path - ",removepath
                        os.remove(removepath)
                    
print "Successfully removed!"
# Out:
# /Users/Vinit/Desktop/CSIhack/dataset
# ...
